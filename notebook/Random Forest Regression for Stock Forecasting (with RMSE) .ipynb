# %%
import yfinance as yf
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
data= pd.read_csv(r"C:\Users\Owner\Downloads\AAPL_stock.csv")
data.head()
# Out:
#          Date               Close                High                 Low  \
# 0         NaN                AAPL                AAPL                AAPL
# 1  2015-01-02    24.2885799407959   24.75733433246641  23.848705532925308
# 2  2015-01-05   23.60433578491211  24.137516414569966  23.417723496745833
# 3  2015-01-06  23.606550216674805  23.866475117609923  23.244430968171436
# 4  2015-01-07  23.937572479248047  24.037543101651647   23.70430543372708
#
#                  Open     Volume
# 0                AAPL       AAPL
# 1  24.746225733732643  212818400
# 2  24.057539235374563  257142000
# 3  23.668754292631863  263188400
# 4    23.8153846563686  160423600

# %% [markdown]
# # Step 2: Load historical stock data

# %%
data = yf.download('AAPL', start='2018-01-01', end='2024-06-01')
df = data[['Close']].copy()
df = df.rename(columns={'Close': 'y'})
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Step 3: Create lag features

# %%
for lag in range(1, 6):  # Using past 5 days
    df[f'lag_{lag}'] = df['y'].shift(lag)

df.dropna(inplace=True)

# %% [markdown]
# # Step 4: Define features and target

# %%
X = df[[f'lag_{i}' for i in range(1, 6)]]
y = df['y']

# %% [markdown]
# # Step 5: Train/Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.2)

# %%
train_size = int(len(df) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %% [markdown]
# # Step 6: Train Random Forest model

# %%
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_11904\650042473.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# RandomForestRegressor(random_state=42)

# %% [markdown]
# # Step 7: Predict and evaluate

# %%
y_pred = model.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE:", rmse)
# Out:
# RMSE: 9.338146704557914

# %% [markdown]
# # Step 8: Plot actual vs predicted prices

# %%
plt.figure(figsize=(12, 5))
plt.plot(y_test.index, y_test, label='Actual')
plt.plot(y_test.index, y_pred, label='Predicted', color='green')
plt.title('Random Forest Regressor: Stock Price Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# # Summary

# %% [raw]
#  1. Created lag features:
#
# a.lag_1, lag_2, lag_3 — previous 3 days' prices.
#
# b.These features are used as input (X), while the actual price is the target (y).
#
# c.Removed rows with NaN caused by shifting (using dropna()).
#
#  2. Split data into:
#
# a.80% training set (X_train, y_train)
#
# b.20% testing set (X_test, y_test)
#
# c.Used manual slicing instead of train_test_split to maintain time series order.
#
#  3.Trained a Random Forest Regressor with 100 trees.
#  4.Calculated Root Mean Squared Error (RMSE) to evaluate accuracy.
# RMSE: 9.3
